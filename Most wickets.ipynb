# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

sns.set_style("darkgrid")

# %%
data=pd.read_csv('C:/Users/Ambuj nayan mishra/Downloads/Most Wickets in Test Cricket .csv')

# %% [markdown]
# <div class="alert alert-block"; style= "background-color:#f2f2f2;">
# <h1 style="color:#0099ff; font-size:40px">Quick Access Link:</h1>
#     <br></br>
#     <a href='#1' style="font-size:20px; color:#ff3300;margin-left:100px">1. Most wicket taker bowler respect to country:</a>
#      <br></br>
#     <a href='#2' style="font-size:20px; color:#ff3300;margin-left:100px">2. Most wicket taker player:</a>
#     <br></br>
#     <a href='#3' style="font-size:20px; color:#ff3300;margin-left:100px">3. Most Matches played by player:</a>
#     <br></br>
#     <a href='#4' style="font-size:20px; color:#ff3300;margin-left:100px">4. Number of Balls throw by bowler:</a>
#     <br></br>
#     <a href='#5' style="font-size:20px; color:#ff3300;margin-left:100px">5. Most Economical bowler:</a>
#     <br></br>
#     <a href='#6' style="font-size:20px; color:#ff3300;margin-left:100px">6. Most 5 and 10 wickets in a match:</a>
#     <br></br>
#     <a href='#7' style="font-size:20px; color:#ff3300;margin-left:100px">7. Matches vs wickets:</a>
#     <br></br>
#     <a href='#8' style="font-size:20px; color:#ff3300;margin-left:100px">8. Balls vs wicket:</a>
#     <br></br>
#     <a href='#9' style="font-size:20px; color:#ff3300;margin-left:100px">9. Total wickets Country Wise:</a>
#     <br></br>
#     <a href='#10' style="font-size:20px; color:#ff3300;margin-left:100px">10. Conclusion:</a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" id='1'>
# <h1 style="color:blue; font-size:30px">1. Most wicket taker bowler respect to country:</h1>
# </div>

# %%
f,ax=plt.subplots(1,1,figsize=(25,10))
sns.countplot(x='Country ',data=data,palette ='bright',order=data['Country '].value_counts().index,saturation=0.95)
for container in ax.containers:
    ax.bar_label(container,color='black',size=20)

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=['Sri Lanka ', 'Australia ', 'England ', 'India ', 'West Indies','South Africa', 'New Zealand ', 'Pakistan ', 'Zimbabwe','Bangladesh '], values=data['Country '].value_counts(), hole=.3)])
fig.show()
# Out:
# <div>                            <div id="74a6e8f0-971f-419c-8b1c-176ba4392d4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a6e8f0-971f-419c-8b1c-176ba4392d4a")) {                    Plotly.newPlot(                        "74a6e8f0-971f-419c-8b1c-176ba4392d4a",                        [{"hole":0.3,"labels":["Sri Lanka ","Australia ","England ","India ","West Indies","South Africa","New Zealand ","Pakistan ","Zimbabwe","Bangladesh "],"values":[18,15,11,9,8,7,7,3,1,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scat ...
#
# var gd = document.getElementById('74a6e8f0-971f-419c-8b1c-176ba4392d4a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display

# %%
data['Country '].value_counts()
# Out:
# Australia       18
# England         15
# India           11
# South Africa     9
# West Indies      8
# New Zealand      7
# Pakistan         7
# Sri Lanka        3
# Zimbabwe         1
# Bangladesh       1
# Name: Country , dtype: int64

# %%
Group_data=data.groupby('Country ')
Group_data.get_group('Australia ')
# Out:
#     Rank         Player     Country   Matches  Innings   Balls    Runs  \
# 1       2        S Warne  Australia       145       273   40705  17995
# 4       5     GD McGrath  Australia       124       243   29248  12186
# 12     13       NM Lyon   Australia       108       204   27983  13732
# 23     24      DK Lillee  Australia        70       132   18467   8493
# 28     29    MG Johnson   Australia        73       140   16001   8891
# 31     32          B Lee  Australia        76       150   16531   9554
# 38     39  CJ McDermott   Australia        71       124   16586   8332
# 39     40      MA Starc   Australia        69       133   14104   7786
# 43     44  JN Gillespie   Australia        71       137   14234   6770
# 47     48      R Benaud   Australia        63       116   19108   6704
# 49     50   GD McKenzie   Australia        60       113   17681   7328
# 63     64   RR Lindwall   Australia        61       113   13650   5251
# 67     68     PM Siddle   Australia        67       126   13907   6777
# 69     70   CV Grimmett   Australia        37        67   14513   5231
# 71     72  JR Hazlewood   Australia        57       107   12235   5573
# 74     75     MG Hughes   Australia        53        97   12285   6017
# 75     76   SCG MacGill   Australia        44        85   11237   6038
# 79     80    JR Thomson   Australia        51        90   10535   5601
#
#     Wickets   Average  Econ   SR    5  10
# 1        708    25.41  2.65  57.4  37  10
# 4        563    21.64  2.49  51.9  29   3
# 12       427    32.15  2.94  65.5  19   3
# 23       355    23.92  2.75  52.0  23   7
# 28       313    28.40  3.33  51.1  12   3
# 31       310    30.81  3.46  53.3  10   0
# 38       291    28.63  3.01  56.9  14   2
# 39       282    27.60  3.31  50.0  13   2
# 43       259    26.13  2.85  54.9   8   0
# 47       248    27.03  2.10  77.0  16   1
# 49       246    29.78  2.48  71.8  16   3
# 63       228    23.03  2.30  59.8  12   0
# 67       221    30.66  2.92  62.9   8   0
# 69       216    24.21  2.16  67.1  21   7
# 71       215    25.92  2.73  56.9   9   0
# 74       212    28.38  2.93  57.9   7   1
# 75       208    29.02  3.22  54.0  12   2
# 79       200    28.00  3.18  52.6   8   0

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='2'>
# <h1 style="color:blue; font-size:30px;">2. Most wicket taker player:</h1>
# </div>

# %%
Group_data['Player '].head(2).values
# Out:
# array(['M Muralidaran ', 'S Warne', 'JM Anderson ', 'A Kumble ',
#        'GD McGrath', 'SCJ Broad', 'CA Walsh ', 'R Ashwin ', 'DW Steyn ',
#        'HMRKB Herath ', 'Sir RJ Hadlee', 'SM Pollock ', 'Wasim Akram ',
#        'CEL Ambrose', 'Waqar Younis ', 'DL Vettori', 'HH Streak ',
#        'Shakib Al Hasan '], dtype=object)

# %%
Group_data['Wickets '].head(2).values
# Out:
# array([800, 708, 640, 619, 563, 537, 519, 442, 439, 433, 431, 421, 414,
#        405, 373, 362, 216, 215], dtype=int64)

# %%
df = px.data.tips()
fig = px.bar(Group_data, x=Group_data['Player '].head(2).values, y=Group_data['Wickets '].head(2).values,
             color=Group_data['Wickets '].head(2),
             labels={'y':'Wickets','x':'Player'}, height=600)
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <div>                            <div id="6c14df58-8948-4e87-8985-30595f92c6ad" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c14df58-8948-4e87-8985-30595f92c6ad")) {                    Plotly.newPlot(                        "6c14df58-8948-4e87-8985-30595f92c6ad",                        [{"alignmentgroup":"True","hovertemplate":"Player=%{x}<br>Wickets=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[800,708,640,619,563,537,519,442,439,433,431,421,414,405,373,362,216,215],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["M Muralidaran ","S Warne","JM Anderson ","A Kumble ","GD McGrath","SCJ Broad","CA Walsh ","R Ashwin ","DW Steyn ","HMRKB Herath ","Sir RJ Hadlee","SM Pollock ","Wasim Akram ","CEL Ambrose","Waqar Younis ","DL Vettori","HH Streak ","Shakib Al Hasan "],"xaxis":"x","y":[800,708,640,619,563,537,519,442,439,433,431,421,414,405,373,362,216,215],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks ...

# %%
df = px.data.tips()
fig = px.bar(Group_data, x=Group_data['Wickets '].head(1).values, y=Group_data['Player '].head(1).values, color=Group_data['Country '].head(1).values, orientation='h',
             height=600,labels={'y':'Players','x':'Wickets'})
fig.show()
# Out:
# <div>                            <div id="da5f272f-4f70-4995-a326-797bdea691b1" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da5f272f-4f70-4995-a326-797bdea691b1")) {                    Plotly.newPlot(                        "da5f272f-4f70-4995-a326-797bdea691b1",                        [{"alignmentgroup":"True","hovertemplate":"color=Sri Lanka <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"Sri Lanka ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sri Lanka ","offsetgroup":"Sri Lanka ","orientation":"h","showlegend":true,"textposition":"auto","x":[800],"xaxis":"x","y":["M Muralidaran "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Australia <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"Australia ","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Australia ","offsetgroup":"Australia ","orientation":"h","showlegend":true,"textposition":"auto","x":[708],"xaxis":"x","y":["S Warne"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=England <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"England ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"England ","offsetgroup":"England ","orientation":"h","showlegend":true,"textposition":"auto","x":[640],"xaxis":"x","y":["JM Anderson "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=India <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"India ","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"India ","offsetgroup":"India ","orientation":"h","showlegend":true,"textposition":"auto","x":[619],"xaxis":"x","y":["A Kumble "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=West Indies<br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"West Indies","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"West Indies","offsetgroup":"West Indies","orientation":"h","showlegend":true,"textposition":"auto","x":[519],"xaxis":"x","y":["CA Walsh "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=South Africa<br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"South Africa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Africa","offsetgroup":"South Africa","orientation":"h","showlegend":true,"textposition":"auto","x":[439],"xaxis":"x","y":["DW Steyn "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=New Zealand <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"New Zealand ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"New Zealand ","offsetgroup":"New Zealand ","orientation":"h","showlegend":true,"textposition":"auto","x":[431],"xaxis":"x","y":["Sir RJ Hadlee"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Pakistan <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"Pakistan ","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Pakistan ","offsetgroup":"Pakistan ","orientation":"h","showlegend":true,"textposition":"auto","x":[414],"xaxis":"x","y":["Wasim Akram "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Zimbabwe<br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"Zimbabwe","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Zimbabwe","offsetgroup":"Zimbabwe","orientation":"h","showlegend":true,"textposition":"auto","x":[216],"xaxis":"x","y":["HH Streak "],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bangladesh <br>Wickets=%{x}<br>Players=%{y}<extra></extra>","legendgroup":"Bangladesh ","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Bangladesh ","offsetgroup":"Bangladesh ","orientation":"h","sh ...

# %%
fig = go.Figure(go.Funnel(
    y = data['Player '].values,
    x = data['Wickets '].values))

fig.show()
# Out:
# <div>                            <div id="22ce02f9-f3c4-4d13-9aa0-3d906647fbd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22ce02f9-f3c4-4d13-9aa0-3d906647fbd5")) {                    Plotly.newPlot(                        "22ce02f9-f3c4-4d13-9aa0-3d906647fbd5",                        [{"x":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"y":["M Muralidaran ","S Warne","JM Anderson ","A Kumble ","GD McGrath","SCJ Broad","CA Walsh ","R Ashwin ","DW Steyn ","N Kapil Dev ","HMRKB Herath ","Sir RJ Hadlee","NM Lyon ","SM Pollock ","Harbhajan Singh ","Wasim Akram ","CEL Ambrose","M Ntini ","IT Botham ","MD Marshall ","Waqar Younis ","Imran Khan ","DL Vettori","DK Lillee","WPUJC Vaas","TG Southee ","AA Donald ","RGD Willis ","MG Johnson ","I Sharma ","Z Khan ","B Lee","M Morkel ","LR Gibbs ","FS Trueman ","TA Boult ","DL Underwood","JH Kallis ","CJ McDermott ","MA Starc ","BS Bedi ","Danish Kaneria","J Garner ","JN Gillespie ","GP Swann","JB Statham ","MA Holding ","R Benaud ","MJ Hoggard ","GD McKenzie ","N Wagner ","K Rabada ","RA Jadeja ","KAJ Roach ","BS Chandrasekhar ","AV Bedser","J Srinath ","Abdul Qadir ","Yasir Shah ","GS Sobers","AR Caddick ","CS Martin ","D Gough ","RR Lindwall ","SJ Harmison ","A Flintoff","VD Philander ","PM Siddle ","CL Cairns","CV Grimmett ","HH Streak ","JR Hazlewood ","Shakib Al Hasan ","Mohammed Shami ","MG Hughes ","SCG MacGill ","Saqlain Mushtaq","AME Roberts ","JA Snow ","JR Thomson "],"type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %% [markdown]
# ### `Observation:-` Most wicket taker bowler is M. Muralidaran.

# %% [markdown]
# ![gettyimages-925950352-612x612.jpg](attachment:gettyimages-925950352-612x612.jpg)

# %% [markdown]
# ### `Observation:- `Second wicket taker bowler is S. Warne.

# %% [markdown]
# ![gettyimages-669844678-612x612.jpg](attachment:gettyimages-669844678-612x612.jpg)

# %%
Group_data['Matches'].max().sort_values(ascending=False)
# Out:
# Country
# England         169
# South Africa    166
# Australia       145
# Sri Lanka       133
# India           132
# West Indies     132
# New Zealand     113
# Pakistan        104
# Zimbabwe         65
# Bangladesh       59
# Name: Matches, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='3'>
# <h1 style="color:blue; font-size:30px;">3. Most Matches played by player:</h1>
# </div>

# %%
Group_data['Matches'].head(2).values
# Out:
# array([133, 145, 169, 132, 124, 152, 132,  86,  93,  93,  86, 108, 104,
#         98,  87, 113,  65,  59], dtype=int64)

# %%
#Group_data['Matches'].max().sort_values(ascending=False)
Group_data['Player '].head(2).values
# Out:
# array(['M Muralidaran ', 'S Warne', 'JM Anderson ', 'A Kumble ',
#        'GD McGrath', 'SCJ Broad', 'CA Walsh ', 'R Ashwin ', 'DW Steyn ',
#        'HMRKB Herath ', 'Sir RJ Hadlee', 'SM Pollock ', 'Wasim Akram ',
#        'CEL Ambrose', 'Waqar Younis ', 'DL Vettori', 'HH Streak ',
#        'Shakib Al Hasan '], dtype=object)

# %%
df = px.data.tips()
fig = px.bar(Group_data, x=Group_data['Player '].head(1).values, y=Group_data['Matches'].head(1).values,
             color=Group_data['Matches'].head(1),labels={'x':'Players','y':'Matches'},height=600,color_continuous_scale=px.colors.sequential.Inferno)
fig.show()
# Out:
# <div>                            <div id="2e694524-3252-4450-b4c6-eaa23b45e9b9" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e694524-3252-4450-b4c6-eaa23b45e9b9")) {                    Plotly.newPlot(                        "2e694524-3252-4450-b4c6-eaa23b45e9b9",                        [{"alignmentgroup":"True","hovertemplate":"Players=%{x}<br>Matches=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[133,145,169,132,132,93,86,104,65,59],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["M Muralidaran ","S Warne","JM Anderson ","A Kumble ","CA Walsh ","DW Steyn ","Sir RJ Hadlee","Wasim Akram ","HH Streak ","Shakib Al Hasan "],"xaxis":"x","y":[133,145,169,132,132,93,86,104,65,59],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillm ...

# %% [markdown]
# ### `Observation:-` Most matches played player JM Anderson

# %% [markdown]
# ![gettyimages-933778864-612x612.jpg](attachment:gettyimages-933778864-612x612.jpg)

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='4'>
# <h1 style="color:blue; font-size:30px;">4. Number of Balls throw by bowler:</h1>
# </div>

# %%
f,ax=plt.subplots(1,1,figsize=(30,16))
sns.barplot(x=Group_data['Player '].head(2).values, y=Group_data['Balls '].head(2).values,palette = 'bright',saturation=0.95)
for container in ax.containers:
    ax.bar_label(container,color='black',size=20)

# %% [markdown]
# ### `Observation:-` Most Balls throw by bowler is M. Muralidaran

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='5'>
# <h1 style="color:blue; font-size:30px;">5. Most Economical bowler:</h1>
# </div>

# %%
df = px.data.tips()
fig = px.bar(Group_data, x=Group_data['Player '].head(1).values, y=Group_data['Econ'].head(1).values,
             color=Group_data['Econ'].head(1),
             labels={'y':'Economical','x':'Player'}, height=600,color_continuous_scale=px.colors.sequential.Magenta)
fig.show()
# Out:
# <div>                            <div id="734d76bf-5eb3-4692-8143-1f9b4dfa868c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("734d76bf-5eb3-4692-8143-1f9b4dfa868c")) {                    Plotly.newPlot(                        "734d76bf-5eb3-4692-8143-1f9b4dfa868c",                        [{"alignmentgroup":"True","hovertemplate":"Player=%{x}<br>Economical=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2.47,2.65,2.8,2.69,2.53,3.24,2.63,2.59,2.69,2.98],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["M Muralidaran ","S Warne","JM Anderson ","A Kumble ","CA Walsh ","DW Steyn ","Sir RJ Hadlee","Wasim Akram ","HH Streak ","Shakib Al Hasan "],"xaxis":"x","y":[2.47,2.65,2.8,2.69,2.53,3.24,2.63,2.59,2.69,2.98],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","w ...

# %% [markdown]
# ### `Observation:-` Most Economical bowler is M. Muralidaran.

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='6'>
# <h1 style="color:blue; font-size:30px;">6. Most 5 and 10 wickets in a match:</h1>
# </div>

# %%
df = px.data.tips()
fig = px.bar(Group_data, y=Group_data['Player '].head(2).values, x=Group_data['5'].head(2).values,
             color=Group_data['5'].head(2),
             labels={'x':'5 Wickets','y':'Player'}, height=600,color_continuous_scale=px.colors.sequential.Jet)
fig.show()
# Out:
# <div>                            <div id="c14f8c45-8702-41d5-9e6e-10b50e473c24" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c14f8c45-8702-41d5-9e6e-10b50e473c24")) {                    Plotly.newPlot(                        "c14f8c45-8702-41d5-9e6e-10b50e473c24",                        [{"alignmentgroup":"True","hovertemplate":"5 Wickets=%{x}<br>Player=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[67,37,31,35,29,19,22,30,26,34,36,16,25,22,22,20,7,18],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[67,37,31,35,29,19,22,30,26,34,36,16,25,22,22,20,7,18],"xaxis":"x","y":["M Muralidaran ","S Warne","JM Anderson ","A Kumble ","GD McGrath","SCJ Broad","CA Walsh ","R Ashwin ","DW Steyn ","HMRKB Herath ","Sir RJ Hadlee","SM Pollock ","Wasim Akram ","CEL Ambrose","Waqar Younis ","DL Vettori","HH Streak ","Shakib Al Hasan "],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"tic ...

# %%
df = px.data.tips()
fig = px.bar(Group_data, x=Group_data['Player '].head(2).values, y=Group_data['10'].head(2).values,
             color=Group_data['10'].head(2),
             labels={'y':'10 Wickets','x':'Player'}, height=600,color_continuous_scale=px.colors.sequential.Blackbody)
fig.show()
# Out:
# <div>                            <div id="d1715741-8d24-47de-9b27-b21132a3d220" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1715741-8d24-47de-9b27-b21132a3d220")) {                    Plotly.newPlot(                        "d1715741-8d24-47de-9b27-b21132a3d220",                        [{"alignmentgroup":"True","hovertemplate":"Player=%{x}<br>10 Wickets=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[22,10,3,8,3,3,3,7,5,9,9,1,5,3,5,3,0,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["M Muralidaran ","S Warne","JM Anderson ","A Kumble ","GD McGrath","SCJ Broad","CA Walsh ","R Ashwin ","DW Steyn ","HMRKB Herath ","Sir RJ Hadlee","SM Pollock ","Wasim Akram ","CEL Ambrose","Waqar Younis ","DL Vettori","HH Streak ","Shakib Al Hasan "],"xaxis":"x","y":[22,10,3,8,3,3,3,7,5,9,9,1,5,3,5,3,0,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x": ...

# %% [markdown]
# ### `Observation:-` Most 5 and 10 wickets taken in a match by M. Muralidaran.

# %% [markdown]
# ![Muttiah-Muralitharan.jpg](attachment:Muttiah-Muralitharan.jpg)

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='7'>
# <h1 style="color:blue; font-size:30px;">7. Matches vs wickets:</h1>
# </div>

# %%
df = px.data.iris()
fig = px.scatter(data, x='Matches', y='Wickets ', size='Wickets ',color='Wickets ')
fig.show()
# Out:
# <div>                            <div id="c5c43143-c1a0-43cb-aa02-fbcf7841c630" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5c43143-c1a0-43cb-aa02-fbcf7841c630")) {                    Plotly.newPlot(                        "c5c43143-c1a0-43cb-aa02-fbcf7841c630",                        [{"hovertemplate":"Matches=%{x}<br>Wickets =%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"coloraxis":"coloraxis","size":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"sizemode":"area","sizeref":2.0,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[133,145,169,132,124,152,132,86,93,131,93,86,108,108,103,104,98,101,102,81,87,88,113,70,111,85,72,90,73,105,92,76,86,79,67,75,86,166,71,69,67,61,58,71,60,70,60,63,67,60,58,52,59,71,58,51,67,67,46,93,62,71,58,61,63,79,64,67,62,37,65,57,59,59,53,44,49,47,49,51],"xaxis":"x","y":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0. ...

# %%
f,ax=plt.subplots(1,1,figsize=(18,10))
#sns.scatterplot(data["Matches"], data["Wickets "],hue=data['Country '])
sns.lineplot(data['Matches'],data['Wickets '], hue =data["Country "])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Wickets '>

# %%
fig = px.scatter(data, x="Matches", y="Wickets ", trendline="ols",
                 labels={"Matches": "Matches",
                         "Wickets ": "Wickets"})
fig.update_layout(title_text='Relationship between Matches and Wickets',
                  title_x=0.5, title_font=dict(size=20))
fig.data[1].line.color = 'red'
fig.show()
# Out:
# <div>                            <div id="a8dfce27-fceb-4077-be05-79f686a57302" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8dfce27-fceb-4077-be05-79f686a57302")) {                    Plotly.newPlot(                        "a8dfce27-fceb-4077-be05-79f686a57302",                        [{"hovertemplate":"Matches=%{x}<br>Wickets=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[133,145,169,132,124,152,132,86,93,131,93,86,108,108,103,104,98,101,102,81,87,88,113,70,111,85,72,90,73,105,92,76,86,79,67,75,86,166,71,69,67,61,58,71,60,70,60,63,67,60,58,52,59,71,58,51,67,67,46,93,62,71,58,61,63,79,64,67,62,37,65,57,59,59,53,44,49,47,49,51],"xaxis":"x","y":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>Wickets  = 3.53641 * Matches + 33.4229<br>R<sup>2</sup>=0.686617<br><br>Matches=%{x}<br>Wickets=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[37,44,46,47,49,49,51,51,52,53,57,58,58,58,58,59,59,59,60,60,60,61,61,62,62,63,63,64,65,67,67,67,67,67,67,69,70,70,71,71,71,71,72,73,75,76,79,79,81,85,86,86,86,86,87,88,90,92,93,93,93,98,101,102,103,104,105,108,108,111,113,124,131,132,132,133,145,152,166,169],"xaxis":"x","y":[164.27025850995136,189.025162807958,196.09799260738845,199.6344075071037,206.70723730653415,206.70723730653415,213.78006710596463,213.78006710596463,217.31648200567986,220.8528969053951,234.99855650425604,238.53497140397127,238.53497140397127,238.53497140397127,238.53497140397127,242.0713863036865,242.0713863036865,242.0713863036865,245.60780120340175,245.60780120340175,245.60780120340175,249.14421610311697,249.14421610311697,252.6806310028322,252.6806310028322,256.21704590254745,256.21704590254745,259.7534608022627,263.2898757019779,270.3627055014084,270.3627055014084,270.3627055014084,270.3627055014084,270.3627055014084,270.3627055014084,277.43553530083886,280.9719502005541,280.9719502005541,284.5083651002693,284.5083651002693,284.5083651002693,284.5083651002693,288.04477999998454,291.58119489969977,298.6540246991303,302.1904395988455,312.7996842979912,312.7996842979912,319.8725140974217,334.0181736962826,337.5545885959978,337.5545885959978,337.5545885959978,337.5545885959978,341.0910034957131,344.6274183954283,351.7002481948588,358.7730779942892,362.3094928940045,362.3094928940045,362.3094928940045,379.99156739258063,390.60081209172637,394.1372269914416,397.6736418911568,401.21005679087204,404.74647169058727,415.355716389733,415.355716389733,425.9649610888787,433.0377908883092,471.9383547851767,496.69325908318336,500.22967398289865,500.22967398289865,503.7660888826139,546.2030676791967,570.9579719772033,620.4677805732166,631.0770252723623],"yaxis":"y","type":"scatter","line":{"color":"red"}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{" ...

# %% [markdown]
# ### `Observation:-` As you can see whosoever played more matches he gets more wickets.

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='8'>
# <h1 style="color:blue; font-size:30px;">8. Balls vs wicket:</h1>
# </div>

# %%
df = px.data.gapminder()
fig = px.line(data, x='Balls ', y='Wickets ', color='Player ', markers=True)
fig.show()
# Out:
# <div>                            <div id="85a211c5-8960-40f3-87f3-a54ea7f48a24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85a211c5-8960-40f3-87f3-a54ea7f48a24")) {                    Plotly.newPlot(                        "85a211c5-8960-40f3-87f3-a54ea7f48a24",                        [{"hovertemplate":"Player =M Muralidaran <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"M Muralidaran ","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"M Muralidaran ","orientation":"v","showlegend":true,"x":[44039],"xaxis":"x","y":[800],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =S Warne<br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"S Warne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"S Warne","orientation":"v","showlegend":true,"x":[40705],"xaxis":"x","y":[708],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =JM Anderson <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"JM Anderson ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"JM Anderson ","orientation":"v","showlegend":true,"x":[36396],"xaxis":"x","y":[640],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =A Kumble <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"A Kumble ","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"A Kumble ","orientation":"v","showlegend":true,"x":[40850],"xaxis":"x","y":[619],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =GD McGrath<br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"GD McGrath","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"GD McGrath","orientation":"v","showlegend":true,"x":[29248],"xaxis":"x","y":[563],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =SCJ Broad<br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"SCJ Broad","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"SCJ Broad","orientation":"v","showlegend":true,"x":[30575],"xaxis":"x","y":[537],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =CA Walsh <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"CA Walsh ","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"CA Walsh ","orientation":"v","showlegend":true,"x":[30019],"xaxis":"x","y":[519],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =R Ashwin <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"R Ashwin ","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"R Ashwin ","orientation":"v","showlegend":true,"x":[23089],"xaxis":"x","y":[442],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =DW Steyn <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"DW Steyn ","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"DW Steyn ","orientation":"v","showlegend":true,"x":[18608],"xaxis":"x","y":[439],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =N Kapil Dev <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"N Kapil Dev ","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"N Kapil Dev ","orientation":"v","showlegend":true,"x":[27740],"xaxis":"x","y":[434],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player =HMRKB Herath <br>Balls =%{x}<br>Wickets =%{y}<extra></extra>","legendgroup":"HMRKB Herath ","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+line ...

# %%
px.defaults.color_continuous_scale = px.colors.sequential.Blackbody
df = px.data.iris()
fig = px.scatter(data, x='Balls ', y='Wickets ', size='Wickets ',color='Wickets ',color_continuous_scale=px.colors.sequential.Jet)
fig.show()
# Out:
# <div>                            <div id="098fcfd9-1b8d-4515-a8ea-2a4ecc5ea2d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("098fcfd9-1b8d-4515-a8ea-2a4ecc5ea2d9")) {                    Plotly.newPlot(                        "098fcfd9-1b8d-4515-a8ea-2a4ecc5ea2d9",                        [{"hovertemplate":"Balls =%{x}<br>Wickets =%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"coloraxis":"coloraxis","size":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"sizemode":"area","sizeref":2.0,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[44039,40705,36396,40850,29248,30575,30019,23089,18608,27740,25993,21918,27983,24353,28580,22627,22103,20834,21815,17584,16224,19458,28814,18467,23438,19352,15519,17357,16001,19160,18785,16531,16498,27115,15178,16689,21862,20232,16586,14104,21364,17697,13169,14234,15349,16056,12680,19108,13909,17681,12845,9908,14627,12916,15963,15918,15104,17126,13697,21599,13558,14026,11821,13650,13375,14951,11391,13907,11698,14513,13559,12235,13529,10605,12285,11237,14070,11135,12021,10535],"xaxis":"x","y":[800,708,640,619,563,537,519,442,439,434,433,431,427,421,417,414,405,390,383,376,373,362,362,355,355,338,330,325,313,311,311,310,309,309,307,301,297,292,291,282,266,261,259,259,255,252,249,248,248,246,244,243,242,242,242,236,236,236,235,235,234,233,229,228,226,226,224,221,218,216,216,215,215,214,212,208,208,202,202,200],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contou ...

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='9'>
# <h1 style="color:blue; font-size:30px;">9. Total wickets Country Wise:</h1>
# </div>

# %%
df = px.data.tips()
fig = px.ecdf(data, x="Matches", y='Wickets ',color='Country ',ecdfnorm=None)
fig.show()
# Out:
# <div>                            <div id="b1f87148-685d-4c31-8040-ffd0e0830722" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1f87148-685d-4c31-8040-ffd0e0830722")) {                    Plotly.newPlot(                        "b1f87148-685d-4c31-8040-ffd0e0830722",                        [{"hovertemplate":"Country =Sri Lanka <br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"Sri Lanka ","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Sri Lanka ","orientation":"v","showlegend":true,"x":[93,111,133],"xaxis":"x","y":[433,788,1588],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =Australia <br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"Australia ","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Australia ","orientation":"v","showlegend":true,"x":[37,44,51,53,57,60,61,63,67,69,70,71,71,73,76,108,124,145],"xaxis":"x","y":[216,424,624,836,1051,1297,1525,1773,1994,2276,2631,2890,3181,3494,3804,4231,4794,5502],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =England <br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"England ","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#00cc96","symbol":"circle"},"mode":"lines","name":"England ","orientation":"v","showlegend":true,"x":[49,51,58,60,62,63,67,67,70,79,86,90,102,152,169],"xaxis":"x","y":[202,438,667,922,1156,1382,1689,1937,2189,2415,2712,3037,3420,3957,4597],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =India <br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"India ","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#ab63fa","symbol":"circle"},"mode":"lines","name":"India ","orientation":"v","showlegend":true,"x":[58,59,59,67,67,86,92,103,105,131,132],"xaxis":"x","y":[242,484,698,964,1200,1642,1953,2370,2681,3115,3734],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =West Indies<br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"West Indies","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#FFA15A","symbol":"circle"},"mode":"lines","name":"West Indies","orientation":"v","showlegend":true,"x":[47,58,60,71,81,93,98,132],"xaxis":"x","y":[202,461,710,952,1328,1563,1968,2487],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =South Africa<br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"South Africa","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#19d3f3","symbol":"circle"},"mode":"lines","name":"South Africa","orientation":"v","showlegend":true,"x":[52,64,72,79,86,93,101,108,166],"xaxis":"x","y":[243,467,797,1106,1415,1854,2244,2665,2957],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =New Zealand <br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"New Zealand ","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#FF6692","symbol":"circle"},"mode":"lines","name":"New Zealand ","orientation":"v","showlegend":true,"x":[58,62,71,75,85,86,113],"xaxis":"x","y":[244,462,695,996,1334,1765,2127],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =Pakistan <br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"Pakistan ","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#B6E880","symbol":"circle"},"mode":"lines","name":"Pakistan ","orientation":"v","showlegend":true,"x":[46,49,61,67,87,88,104],"xaxis":"x","y":[235,443,704,940,1313,1675,2089],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country =Zimbabwe<br>Matches=%{x}<br>sum of Wickets =%{y}<extra></extra>","legendgroup":"Zimbabwe","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#FF97FF","symbol":"circle"},"mode":"lines","name" ...

# %%
df = px.data.gapminder()
fig = px.sunburst(data, path=['Country ','Player ','Matches', 'Wickets '], values='Wickets ',
                  color='Wickets ', hover_data=['Player '],height=800)
fig.show()
# Out:
# <div>                            <div id="4c7b5974-b505-4a34-988f-42f2afc17fb7" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c7b5974-b505-4a34-988f-42f2afc17fb7")) {                    Plotly.newPlot(                        "4c7b5974-b505-4a34-988f-42f2afc17fb7",                        [{"branchvalues":"total","customdata":[["JR Thomson ",200.0],["AME Roberts ",202.0],["JA Snow ",202.0],["SCG MacGill ",208.0],["Saqlain Mushtaq",208.0],["MG Hughes ",212.0],["Mohammed Shami ",214.0],["JR Hazlewood ",215.0],["Shakib Al Hasan ",215.0],["CV Grimmett ",216.0],["HH Streak ",216.0],["CL Cairns",218.0],["PM Siddle ",221.0],["VD Philander ",224.0],["SJ Harmison ",226.0],["A Flintoff",226.0],["RR Lindwall ",228.0],["D Gough ",229.0],["CS Martin ",233.0],["AR Caddick ",234.0],["Yasir Shah ",235.0],["GS Sobers",235.0],["AV Bedser",236.0],["Abdul Qadir ",236.0],["J Srinath ",236.0],["BS Chandrasekhar ",242.0],["RA Jadeja ",242.0],["KAJ Roach ",242.0],["K Rabada ",243.0],["N Wagner ",244.0],["GD McKenzie ",246.0],["R Benaud ",248.0],["MJ Hoggard ",248.0],["MA Holding ",249.0],["JB Statham ",252.0],["GP Swann",255.0],["J Garner ",259.0],["JN Gillespie ",259.0],["Danish Kaneria",261.0],["BS Bedi ",266.0],["MA Starc ",282.0],["CJ McDermott ",291.0],["JH Kallis ",292.0],["DL Underwood",297.0],["TA Boult ",301.0],["FS Trueman ",307.0],["LR Gibbs ",309.0],["M Morkel ",309.0],["B Lee",310.0],["Z Khan ",311.0],["I Sharma ",311.0],["MG Johnson ",313.0],["RGD Willis ",325.0],["AA Donald ",330.0],["TG Southee ",338.0],["DK Lillee",355.0],["WPUJC Vaas",355.0],["Imran Khan ",362.0],["DL Vettori",362.0],["Waqar Younis ",373.0],["MD Marshall ",376.0],["IT Botham ",383.0],["M Ntini ",390.0],["CEL Ambrose",405.0],["Wasim Akram ",414.0],["Harbhajan Singh ",417.0],["SM Pollock ",421.0],["NM Lyon ",427.0],["Sir RJ Hadlee",431.0],["HMRKB Herath ",433.0],["N Kapil Dev ",434.0],["DW Steyn ",439.0],["R Ashwin ",442.0],["CA Walsh ",519.0],["SCJ Broad",537.0],["GD McGrath",563.0],["A Kumble ",619.0],["JM Anderson ",640.0],["S Warne",708.0],["M Muralidaran ",800.0],["CV Grimmett ",216.0],["SCG MacGill ",208.0],["Yasir Shah ",235.0],["AME Roberts ",202.0],["JA Snow ",202.0],["Saqlain Mushtaq",208.0],["AV Bedser",236.0],["JR Thomson ",200.0],["K Rabada ",243.0],["MG Hughes ",212.0],["JR Hazlewood ",215.0],["BS Chandrasekhar ",242.0],["D Gough ",229.0],["J Garner ",259.0],["N Wagner ",244.0],["Mohammed Shami ",214.0],["RA Jadeja ",242.0],["Shakib Al Hasan ",215.0],["GD McKenzie ",246.0],["GP Swann",255.0],["MA Holding ",249.0],["Danish Kaneria",261.0],["RR Lindwall ",228.0],["AR Caddick ",234.0],["CL Cairns",218.0],["R Benaud ",248.0],["SJ Harmison ",226.0],["VD Philander ",224.0],["HH Streak ",216.0],["Abdul Qadir ",236.0],["BS Bedi ",266.0],["FS Trueman ",307.0],["J Srinath ",236.0],["MJ Hoggard ",248.0],["PM Siddle ",221.0],["MA Starc ",282.0],["DK Lillee",355.0],["JB Statham ",252.0],["CJ McDermott ",291.0],["CS Martin ",233.0],["JN Gillespie ",259.0],["KAJ Roach ",242.0],["AA Donald ",330.0],["MG Johnson ",313.0],["TA Boult ",301.0],["B Lee",310.0],["A Flintoff",226.0],["LR Gibbs ",309.0],["MD Marshall ",376.0],["TG Southee ",338.0],["DL Underwood",297.0],["M Morkel ",309.0],["R Ashwin ",442.0],["Sir RJ Hadlee",431.0],["Waqar Younis ",373.0],["Imran Khan ",362.0],["RGD Willis ",325.0],["Z Khan ",311.0],["DW Steyn ",439.0],["GS Sobers",235.0],["HMRKB Herath ",433.0],["CEL Ambrose",405.0],["M Ntini ",390.0],["IT Botham ",383.0],["Harbhajan Singh ",417.0],["Wasim Akram ",414.0],["I Sharma ",311.0],["NM Lyon ",427.0],["SM Pollock ",421.0],["WPUJC Vaas",355.0],["DL Vettori",362.0],["GD McGrath",563.0],["N Kapil Dev ",434.0],["A Kumble ",619.0],["CA Walsh ",519.0],["M Muralidaran ",800.0],["S Warne",708.0],["SCJ Broad",537.0],["JH Ka ...

# %% [markdown]
# <div class="alert alert-block alert-danger" id ='10'>
# <h1 style="color:blue; font-size:30px;">10. Conclusion:</h1>
# </div>

# %% [markdown]
# ### Eleven years ago, Muttiah Muralitharan became the first and till now the only man to have picked up 800 wickets in Test cricket. While the saying goes that records are meant to be broken, this particular achievement of Murali may be a feat too high for anyone to achieve.

# %% [markdown]
# ![gettyimages-103030214-612x612.jpg](attachment:gettyimages-103030214-612x612.jpg)

# %% [markdown]
# ![thank-you-words-written-vintage-letterpress-type-34621434.jpg](attachment:thank-you-words-written-vintage-letterpress-type-34621434.jpg)
